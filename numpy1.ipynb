# %%
import numpy as np

# %%
arr = np.array([5, 10, 15, 20, 25, 30, 35, 40, 45, 50])

# %%
print(arr[1::3])
# Out:
# [10 25 40]

# %%
print(arr[-4:])
# Out:
# [35 40 45 50]

# %%
arr[::2] = -1
print(arr)
# Out:
# [-1 10 -1 20 -1 30 -1 40 -1 50]

# %%
fancy = arr[[2, 4, 6, 8]]
print(fancy)
# Out:
# [-1 -1 -1 -1]
